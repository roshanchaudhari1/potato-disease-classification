# %%
# ✅ Updated Potato Leaf Disease Detection Project (with Generalization, Extra Class, & Robust Pipeline)

import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import numpy as np
import os
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix

# 1. Load & Prepare Dataset (with Additional 'Other' Class)
img_size = (224, 224)
batch_size = 32
data_path = r"C:\Users\chaud\Downloads\PlantVillage"  # Ensure it has 4 subfolders: Early_blight, Late_blight, healthy, Other

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_path,
    validation_split=0.2,
    subset="training",
    seed=42,
    image_size=img_size,
    batch_size=batch_size
)
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_path,
    validation_split=0.2,
    subset="validation",
    seed=42,
    image_size=img_size,
    batch_size=batch_size
)
class_names = train_ds.class_names

# 2. Prefetching and Performance
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)

# 3. Data Augmentation Layer
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
    layers.RandomContrast(0.2),
    layers.RandomBrightness(factor=0.2),
])

# 4. Build Model with Transfer Learning (MobileNetV2)
base_model = tf.keras.applications.MobileNetV2(input_shape=img_size + (3,),
                                               include_top=False,
                                               weights='imagenet')
base_model.trainable = False

model = models.Sequential([
    data_augmentation,
    layers.Rescaling(1./255),
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dropout(0.3),
    layers.Dense(len(class_names), activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# 5. Callbacks
callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True),
    tf.keras.callbacks.ReduceLROnPlateau(factor=0.2, patience=3)
]

# 6. Train Model
history = model.fit(train_ds,
                    validation_data=val_ds,
                    epochs=25,
                    callbacks=callbacks)

# 7. Evaluate Model
val_images, val_labels = [], []
for images, labels in val_ds:
    val_images.append(images)
    val_labels.append(labels)
val_images = tf.concat(val_images, axis=0)
val_labels = tf.concat(val_labels, axis=0)

predictions = model.predict(val_images)
y_pred = np.argmax(predictions, axis=1)
y_true = val_labels.numpy()

print("\n\U0001F50D Classification Report:\n")
print(classification_report(y_true, y_pred, target_names=class_names))
print(f"\n\u2705 Accuracy: {np.mean(y_pred == y_true) * 100:.2f}%")

# 8. Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names,
            yticklabels=class_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# 9. Save the Model
model.save("potato_leaf_model_generalized.h5")

# Optional: Grad-CAM (can be added if needed)
# Out:
# Found 2152 files belonging to 3 classes.
# Using 1722 files for training.
# Found 2152 files belonging to 3 classes.
# Using 430 files for validation.
# ...
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Epoch 1/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.6190 - loss: 0.8574 - val_accuracy: 0.8953 - val_loss: 0.2846 - learning_rate: 0.0010
# Epoch 2/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.8959 - loss: 0.2781 - val_accuracy: 0.9651 - val_loss: 0.1749 - learning_rate: 0.0010
# Epoch 3/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.9423 - loss: 0.1810 - val_accuracy: 0.9651 - val_loss: 0.1315 - learning_rate: 0.0010
# Epoch 4/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.9346 - loss: 0.1703 - val_accuracy: 0.9698 - val_loss: 0.1233 - learning_rate: 0.0010
# Epoch 5/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 74s 1s/step - accuracy: 0.9575 - loss: 0.1261 - val_accuracy: 0.9674 - val_loss: 0.1105 - learning_rate: 0.0010
# Epoch 6/25
# ...
